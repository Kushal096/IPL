# %%
import pandas as pd
import numpy as np

# %%
df_deliveries = pd.read_csv('CSV/deliveries.csv')
df_matches = pd.read_csv('CSV/matches.csv')

# %%
df_deliveries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260920 entries, 0 to 260919
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          260920 non-null  int64
#  1   inning            260920 non-null  int64
#  2   batting_team      260920 non-null  object
#  3   bowling_team      260920 non-null  object
#  4   over              260920 non-null  int64
#  5   ball              260920 non-null  int64
#  6   batter            260920 non-null  object
#  7   bowler            260920 non-null  object
#  8   non_striker       260920 non-null  object
#  9   batsman_runs      260920 non-null  int64
#  10  extra_runs        260920 non-null  int64
#  11  total_runs        260920 non-null  int64
#  12  extras_type       14125 non-null   object
#  13  is_wicket         260920 non-null  int64
#  14  player_dismissed  12950 non-null   object
#  15  dismissal_kind    12950 non-null   object
#  16  fielder           9354 non-null    object
# dtypes: int64(8), object(9)
# memory usage: 33.8+ MB

# %%
df_deliveries.isna().sum()
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batter                   0
# bowler                   0
# non_striker              0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# extras_type         246795
# is_wicket                0
# player_dismissed    247970
# dismissal_kind      247970
# fielder             251566
# dtype: int64

# %%
df_deliveries
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260915   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260916   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260917   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260918   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260919   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
#         over  ball       batter         bowler  non_striker  batsman_runs  \
# 0          0     1   SC Ganguly        P Kumar  BB McCullum             0
# 1          0     2  BB McCullum        P Kumar   SC Ganguly             0
# 2          0     3  BB McCullum        P Kumar   SC Ganguly             0
# 3          0     4  BB McCullum        P Kumar   SC Ganguly             0
# 4          0     5  BB McCullum        P Kumar   SC Ganguly             0
# ...      ...   ...          ...            ...          ...           ...
# 260915     9     5      SS Iyer     AK Markram      VR Iyer             1
# 260916     9     6      VR Iyer     AK Markram      SS Iyer             1
# 260917    10     1      VR Iyer  Shahbaz Ahmed      SS Iyer             1
# 260918    10     2      SS Iyer  Shahbaz Ahmed      VR Iyer             1
# 260919    10     3      VR Iyer  Shahbaz Ahmed      SS Iyer             1
#
#         extra_runs  total_runs extras_type  is_wicket player_dismissed  \
# 0                1           1     legbyes          0              NaN
# 1                0           0         NaN          0              NaN
# 2                1           1       wides          0              NaN
# 3                0           0         NaN          0              NaN
# 4                0           0         NaN          0              NaN
# ...            ...         ...         ...        ...              ...
# 260915           0           1         NaN          0              NaN
# 260916           0           1         NaN          0              NaN
# 260917           0           1         NaN          0              NaN
# 260918           0           1         NaN          0              NaN
# 260919           0           1         NaN          0              NaN
#
#        dismissal_kind fielder
# 0                 NaN     NaN
# 1                 NaN     NaN
# 2                 NaN     NaN
# 3                 NaN     NaN
# 4                 NaN     NaN
# ...               ...     ...
# 260915            NaN     NaN
# 260916            NaN     NaN
# 260917            NaN     NaN
# 260918            NaN     NaN
# 260919            NaN     NaN
#
# [260920 rows x 17 columns]

# %%
df_deliveries.shape
# Out:
# (260920, 17)

# %%
df_matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1095 non-null   int64
#  1   season           1095 non-null   object
#  2   city             1044 non-null   object
#  3   date             1095 non-null   object
#  4   match_type       1095 non-null   object
#  5   player_of_match  1090 non-null   object
#  6   venue            1095 non-null   object
#  7   team1            1095 non-null   object
#  8   team2            1095 non-null   object
#  9   toss_winner      1095 non-null   object
#  10  toss_decision    1095 non-null   object
#  11  winner           1090 non-null   object
#  12  result           1095 non-null   object
#  13  result_margin    1076 non-null   float64
#  14  target_runs      1092 non-null   float64
#  15  target_overs     1092 non-null   float64
#  16  super_over       1095 non-null   object
#  17  method           21 non-null     object
#  18  umpire1          1095 non-null   object
#  19  umpire2          1095 non-null   object
# dtypes: float64(3), int64(1), object(16)
# memory usage: 171.2+ KB

# %%
df_matches.isna().sum()
# Out:
# id                    0
# season                0
# city                 51
# date                  0
# match_type            0
# player_of_match       5
# venue                 0
# team1                 0
# team2                 0
# toss_winner           0
# toss_decision         0
# winner                5
# result                0
# result_margin        19
# target_runs           3
# target_overs          3
# super_over            0
# method             1074
# umpire1               0
# umpire2               0
# dtype: int64

# %%
df_matches.shape
# Out:
# (1095, 20)

# %%
df_matches
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
#                                                   venue  \
# 0                                 M Chinnaswamy Stadium
# 1            Punjab Cricket Association Stadium, Mohali
# 2                                      Feroz Shah Kotla
# 3                                      Wankhede Stadium
# 4                                          Eden Gardens
# ...                                                 ...
# 1090  Rajiv Gandhi International Stadium, Uppal, Hyd...
# 1091                   Narendra Modi Stadium, Ahmedabad
# 1092                   Narendra Modi Stadium, Ahmedabad
# 1093           MA Chidambaram Stadium, Chepauk, Chennai
# 1094           MA Chidambaram Stadium, Chepauk, Chennai
#
#                             team1                        team2  \
# 0     Royal Challengers Bangalore        Kolkata Knight Riders
# 1                 Kings XI Punjab          Chennai Super Kings
# 2                Delhi Daredevils             Rajasthan Royals
# 3                  Mumbai Indians  Royal Challengers Bangalore
# 4           Kolkata Knight Riders              Deccan Chargers
# ...                           ...                          ...
# 1090                 Punjab Kings          Sunrisers Hyderabad
# 1091          Sunrisers Hyderabad        Kolkata Knight Riders
# 1092  Royal Challengers Bengaluru             Rajasthan Royals
# 1093          Sunrisers Hyderabad             Rajasthan Royals
# 1094          Sunrisers Hyderabad        Kolkata Knight Riders
#
#                       toss_winner toss_decision                       winner  \
# 0     Royal Challengers Bangalore         field        Kolkata Knight Riders
# 1             Chennai Super Kings           bat          Chennai Super Kings
# 2                Rajasthan Royals           bat             Delhi Daredevils
# 3                  Mumbai Indians           bat  Royal Challengers Bangalore
# 4                 Deccan Chargers           bat        Kolkata Knight Riders
# ...                           ...           ...                          ...
# 1090                 Punjab Kings           bat          Sunrisers Hyderabad
# 1091          Sunrisers Hyderabad           bat        Kolkata Knight Riders
# 1092             Rajasthan Royals         field             Rajasthan Royals
# 1093             Rajasthan Royals         field          Sunrisers Hyderabad
# 1094          Sunrisers Hyderabad           bat        Kolkata Knight Riders
#
#        result  result_margin  target_runs  target_overs super_over method  \
# 0        runs          140.0        223.0          20.0          N    NaN
# 1        runs           33.0        241.0          20.0          N    NaN
# 2     wickets            9.0        130.0          20.0          N    NaN
# 3     wickets            5.0        166.0          20.0          N    NaN
# 4     wickets            5.0        111.0          20.0          N    NaN
# ...       ...            ...          ...           ...        ...    ...
# 1090  wickets            4.0        215.0          20.0          N    NaN
# 1091  wickets            8.0        160.0          20.0          N    NaN
# 1092  wickets            4.0        173.0          20.0          N    NaN
# 1093     runs           36.0        176.0          20.0          N    NaN
# 1094  wickets            8.0        114.0          20.0          N    NaN
#
#                     umpire1               umpire2
# 0                 Asad Rauf           RE Koertzen
# 1                 MR Benson            SL Shastri
# 2                 Aleem Dar        GA Pratapkumar
# 3                  SJ Davis             DJ Harper
# 4                 BF Bowden           K Hariharan
# ...                     ...                   ...
# 1090            Nitin Menon             VK Sharma
# 1091           AK Chaudhary              R Pandit
# 1092  KN Ananthapadmanabhan  MV Saidharshan Kumar
# 1093            Nitin Menon             VK Sharma
# 1094          J Madanagopal           Nitin Menon
#
# [1095 rows x 20 columns]

# %%
df_matches['team1'].value_counts()
# Out:
# team1
# Royal Challengers Bangalore    135
# Chennai Super Kings            128
# Mumbai Indians                 123
# Kolkata Knight Riders          121
# Rajasthan Royals               101
# Kings XI Punjab                 92
# Sunrisers Hyderabad             86
# Delhi Daredevils                85
# Delhi Capitals                  41
# Deccan Chargers                 39
# Punjab Kings                    31
# Lucknow Super Giants            23
# Pune Warriors                   23
# Gujarat Titans                  21
# Gujarat Lions                   16
# Royal Challengers Bengaluru      9
# Kochi Tuskers Kerala             7
# Rising Pune Supergiant           7
# Rising Pune Supergiants          7
# Name: count, dtype: int64

# %%
teams = [
    'Sunrisers Hyderabad', 'Mumbai Indians', 'Royal Challengers Bengaluru',
    'Kolkata Knight Riders', 'Punjab Kings', 'Chennai Super Kings',
    'Rajasthan Royals', 'Delhi Capitals', 'Gujarat Titans', 'Lucknow Super Giants'
]

# %%
df_matches['team1'] = df_matches['team1'].str.replace('Delhi Daredevils','Delhi Capitals')
df_matches['team2'] = df_matches['team2'].str.replace('Delhi Daredevils','Delhi Capitals')

df_matches['team1'] = df_matches['team1'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
df_matches['team2'] = df_matches['team2'].str.replace('Deccan Chargers','Sunrisers Hyderabad')

df_matches['team1'] = df_matches['team1'].str.replace('Kings XI Punjab','Punjab Kings')
df_matches['team2'] = df_matches['team2'].str.replace('Kings XI Punjab','Punjab Kings')

df_matches['team1'] = df_matches['team1'].str.replace('Royal Challengers Bangalore','Royal Challengers Bengaluru')
df_matches['team2'] = df_matches['team2'].str.replace('Royal Challengers Bangalore','Royal Challengers Bengaluru')

# %%
df_matches = df_matches[df_matches['team1'].isin(teams)]
df_matches = df_matches[df_matches['team2'].isin(teams)]

# %%
print(df_matches['id'].nunique())
print(df_deliveries['match_id'].nunique())
# Out:
# 980
# 1095

# %%
df_matches = df_matches[df_matches['method'].isna()]

# %%
print(df_matches['id'].nunique())
print(df_deliveries['match_id'].nunique())
# Out:
# 963
# 1095

# %%
df_matches.groupby('city')['venue'].unique()
# Out:
# city
# Abu Dhabi         [Sheikh Zayed Stadium, Zayed Cricket Stadium, ...
# Ahmedabad         [Sardar Patel Stadium, Motera, Narendra Modi S...
# Bangalore                                   [M Chinnaswamy Stadium]
# Bengaluru         [M.Chinnaswamy Stadium, M Chinnaswamy Stadium,...
# Bloemfontein                                      [OUTsurance Oval]
# Cape Town                                                [Newlands]
# Centurion                                         [SuperSport Park]
# Chandigarh        [Punjab Cricket Association Stadium, Mohali, P...
# Chennai           [MA Chidambaram Stadium, Chepauk, MA Chidambar...
# Cuttack                                          [Barabati Stadium]
# Delhi             [Feroz Shah Kotla, Arun Jaitley Stadium, Arun ...
# Dharamsala        [Himachal Pradesh Cricket Association Stadium,...
# Dubai                         [Dubai International Cricket Stadium]
# Durban                                                  [Kingsmead]
# East London                                          [Buffalo Park]
# Guwahati                      [Barsapara Cricket Stadium, Guwahati]
# Hyderabad         [Rajiv Gandhi International Stadium, Uppal, Ra...
# Indore                                     [Holkar Cricket Stadium]
# Jaipur            [Sawai Mansingh Stadium, Sawai Mansingh Stadiu...
# Johannesburg                                [New Wanderers Stadium]
# Kimberley                                   [De Beers Diamond Oval]
# Kolkata                       [Eden Gardens, Eden Gardens, Kolkata]
# Lucknow           [Bharat Ratna Shri Atal Bihari Vajpayee Ekana ...
# Mohali            [Maharaja Yadavindra Singh International Crick...
# Mumbai            [Wankhede Stadium, Dr DY Patil Sports Academy,...
# Nagpur               [Vidarbha Cricket Association Stadium, Jamtha]
# Navi Mumbai                    [Dr DY Patil Sports Academy, Mumbai]
# Port Elizabeth                                   [St George's Park]
# Pune              [Subrata Roy Sahara Stadium, Maharashtra Crick...
# Raipur            [Shaheed Veer Narayan Singh International Stad...
# Ranchi                         [JSCA International Stadium Complex]
# Sharjah                                   [Sharjah Cricket Stadium]
# Visakhapatnam     [Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket S...
# Name: venue, dtype: object

# %%
df_matches
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
#                                                   venue  \
# 0                                 M Chinnaswamy Stadium
# 1            Punjab Cricket Association Stadium, Mohali
# 2                                      Feroz Shah Kotla
# 3                                      Wankhede Stadium
# 4                                          Eden Gardens
# ...                                                 ...
# 1090  Rajiv Gandhi International Stadium, Uppal, Hyd...
# 1091                   Narendra Modi Stadium, Ahmedabad
# 1092                   Narendra Modi Stadium, Ahmedabad
# 1093           MA Chidambaram Stadium, Chepauk, Chennai
# 1094           MA Chidambaram Stadium, Chepauk, Chennai
#
#                             team1                        team2  \
# 0     Royal Challengers Bengaluru        Kolkata Knight Riders
# 1                    Punjab Kings          Chennai Super Kings
# 2                  Delhi Capitals             Rajasthan Royals
# 3                  Mumbai Indians  Royal Challengers Bengaluru
# 4           Kolkata Knight Riders          Sunrisers Hyderabad
# ...                           ...                          ...
# 1090                 Punjab Kings          Sunrisers Hyderabad
# 1091          Sunrisers Hyderabad        Kolkata Knight Riders
# 1092  Royal Challengers Bengaluru             Rajasthan Royals
# 1093          Sunrisers Hyderabad             Rajasthan Royals
# 1094          Sunrisers Hyderabad        Kolkata Knight Riders
#
#                       toss_winner toss_decision                       winner  \
# 0     Royal Challengers Bangalore         field        Kolkata Knight Riders
# 1             Chennai Super Kings           bat          Chennai Super Kings
# 2                Rajasthan Royals           bat             Delhi Daredevils
# 3                  Mumbai Indians           bat  Royal Challengers Bangalore
# 4                 Deccan Chargers           bat        Kolkata Knight Riders
# ...                           ...           ...                          ...
# 1090                 Punjab Kings           bat          Sunrisers Hyderabad
# 1091          Sunrisers Hyderabad           bat        Kolkata Knight Riders
# 1092             Rajasthan Royals         field             Rajasthan Royals
# 1093             Rajasthan Royals         field          Sunrisers Hyderabad
# 1094          Sunrisers Hyderabad           bat        Kolkata Knight Riders
#
#        result  result_margin  target_runs  target_overs super_over method  \
# 0        runs          140.0        223.0          20.0          N    NaN
# 1        runs           33.0        241.0          20.0          N    NaN
# 2     wickets            9.0        130.0          20.0          N    NaN
# 3     wickets            5.0        166.0          20.0          N    NaN
# 4     wickets            5.0        111.0          20.0          N    NaN
# ...       ...            ...          ...           ...        ...    ...
# 1090  wickets            4.0        215.0          20.0          N    NaN
# 1091  wickets            8.0        160.0          20.0          N    NaN
# 1092  wickets            4.0        173.0          20.0          N    NaN
# 1093     runs           36.0        176.0          20.0          N    NaN
# 1094  wickets            8.0        114.0          20.0          N    NaN
#
#                     umpire1               umpire2
# 0                 Asad Rauf           RE Koertzen
# 1                 MR Benson            SL Shastri
# 2                 Aleem Dar        GA Pratapkumar
# 3                  SJ Davis             DJ Harper
# 4                 BF Bowden           K Hariharan
# ...                     ...                   ...
# 1090            Nitin Menon             VK Sharma
# 1091           AK Chaudhary              R Pandit
# 1092  KN Ananthapadmanabhan  MV Saidharshan Kumar
# 1093            Nitin Menon             VK Sharma
# 1094          J Madanagopal           Nitin Menon
#
# [963 rows x 20 columns]

# %%
df_deliveries.head(1)
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball      batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1  SC Ganguly  P Kumar  BB McCullum             0           1
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# 0           1     legbyes          0              NaN            NaN     NaN

# %%
df_matches['venue_clean'] = (
    df_matches['venue']
    .str.strip()
    .str.lower()
    .str.split(",").str[0]
)

# %%
df_matches['venue_clean'].value_counts()
# Out:
# venue_clean
# wankhede stadium                                                109
# eden gardens                                                     84
# ma chidambaram stadium                                           81
# rajiv gandhi international stadium                               69
# m chinnaswamy stadium                                            67
# sawai mansingh stadium                                           52
# feroz shah kotla                                                 50
# dubai international cricket stadium                              46
# punjab cricket association stadium                               32
# dr dy patil sports academy                                       30
# sheikh zayed stadium                                             29
# arun jaitley stadium                                             29
# sharjah cricket stadium                                          28
# brabourne stadium                                                27
# narendra modi stadium                                            23
# maharashtra cricket association stadium                          23
# punjab cricket association is bindra stadium                     22
# m.chinnaswamy stadium                                            15
# kingsmead                                                        14
# bharat ratna shri atal bihari vajpayee ekana cricket stadium     14
# himachal pradesh cricket association stadium                     13
# sardar patel stadium                                             12
# dr. y.s. rajasekhara reddy aca-vdca cricket stadium              11
# supersport park                                                  11
# zayed cricket stadium                                             8
# new wanderers stadium                                             8
# st george's park                                                  7
# newlands                                                          6
# barabati stadium                                                  6
# jsca international stadium complex                                6
# holkar cricket stadium                                            6
# maharaja yadavindra singh international cricket stadium           5
# shaheed veer narayan singh international stadium                  5
# de beers diamond oval                                             3
# buffalo park                                                      3
# barsapara cricket stadium                                         3
# vidarbha cricket association stadium                              3
# outsurance oval                                                   2
# subrata roy sahara stadium                                        1
# Name: count, dtype: int64

# %%
venue_mapping = {
    # Delhi
    "feroz shah kotla": "arun jaitley stadium",
    "arun jaitley stadium": "arun jaitley stadium",

    # Ahmedabad
    "sardar patel stadium": "narendra modi stadium",
    "motera": "narendra modi stadium",
    "narendra modi stadium": "narendra modi stadium",

    # Mohali
    "punjab cricket association stadium": "punjab cricket association is bindra stadium",
    "punjab cricket association is bindra stadium": "punjab cricket association is bindra stadium",

    # Pune
    "subrata roy sahara stadium": "maharashtra cricket association stadium",
    "maharashtra cricket association stadium": "maharashtra cricket association stadium",

    # Abu Dhabi
    "sheikh zayed stadium": "zayed cricket stadium",
    "zayed cricket stadium": "zayed cricket stadium",

    # Chennai
    "ma chidambaram stadium": "ma chidambaram stadium",

    # Mumbai
    "wankhede stadium": "wankhede stadium",
    "brabourne stadium": "brabourne stadium",
    "dr dy patil sports academy": "dr dy patil sports academy",

    # Hyderabad
    "rajiv gandhi international stadium": "rajiv gandhi international stadium",

    # Visakhapatnam
    "dr. y.s. rajasekhara reddy aca-vdca cricket stadium": "dr. y.s. rajasekhara reddy aca-vdca cricket stadium",

    # Jaipur
    "sawai mansingh stadium": "sawai mansingh stadium",

    # Nagpur
    "vidarbha cricket association stadium": "vidarbha cricket association stadium",

    # Lucknow
    "bharat ratna shri atal bihari vajpayee ekana cricket stadium": "bharat ratna shri atal bihari vajpayee ekana cricket stadium",

    # Ranchi
    "jsca international stadium complex": "jsca international stadium complex",

    # Raipur
    "shaheed veer narayan singh international stadium": "shaheed veer narayan singh international stadium",

    # Indore
    "holkar cricket stadium": "holkar cricket stadium",

    # Bangalore
    "m chinnaswamy stadium": "m chinnaswamy stadium",

    # Kolkata
    "eden gardens": "eden gardens",

    # International (South Africa / UAE)
    "newlands": "newlands",
    "kingsmead": "kingsmead",
    "supersport park": "supersport park",
    "st george's park": "st george's park",
    "new wanderers stadium": "new wanderers stadium",
    "buffalo park": "buffalo park",
    "outsurance oval": "outsurance oval",
    "de beers diamond oval": "de beers diamond oval",
    "barsapara cricket stadium": "barsapara cricket stadium",
    "sharjah cricket stadium": "sharjah cricket stadium",
    "dubai international cricket stadium": "dubai international cricket stadium",
    "maharaja yadavindra singh international cricket stadium": "maharaja yadavindra singh international cricket stadium",
}

# %%
df_matches['venue_clean'] = (
    df_matches['venue_clean']
    .str.strip().str.lower()
    .replace(venue_mapping)
)

# %%
df_matches.drop('venue', axis=1,inplace=True)
df_matches.rename(columns={'venue_clean':'venue'},inplace=True)

# %%
df_matches.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'target_runs', 'target_overs', 'super_over', 'method',
#        'umpire1', 'umpire2', 'venue'],
#       dtype='object')

# %%
df_matches.groupby('city')['venue'].unique()
# Out:
# city
# Abu Dhabi                                   [zayed cricket stadium]
# Ahmedabad                                   [narendra modi stadium]
# Bangalore                                   [m chinnaswamy stadium]
# Bengaluru            [m.chinnaswamy stadium, m chinnaswamy stadium]
# Bloemfontein                                      [outsurance oval]
# Cape Town                                                [newlands]
# Centurion                                         [supersport park]
# Chandigarh           [punjab cricket association is bindra stadium]
# Chennai                                    [ma chidambaram stadium]
# Cuttack                                          [barabati stadium]
# Delhi                                        [arun jaitley stadium]
# Dharamsala           [himachal pradesh cricket association stadium]
# Dubai                         [dubai international cricket stadium]
# Durban                                                  [kingsmead]
# East London                                          [buffalo park]
# Guwahati                                [barsapara cricket stadium]
# Hyderabad                      [rajiv gandhi international stadium]
# Indore                                     [holkar cricket stadium]
# Jaipur                                     [sawai mansingh stadium]
# Johannesburg                                [new wanderers stadium]
# Kimberley                                   [de beers diamond oval]
# Kolkata                                              [eden gardens]
# Lucknow           [bharat ratna shri atal bihari vajpayee ekana ...
# Mohali            [maharaja yadavindra singh international crick...
# Mumbai            [wankhede stadium, dr dy patil sports academy,...
# Nagpur                       [vidarbha cricket association stadium]
# Navi Mumbai                            [dr dy patil sports academy]
# Port Elizabeth                                   [st george's park]
# Pune                      [maharashtra cricket association stadium]
# Raipur            [shaheed veer narayan singh international stad...
# Ranchi                         [jsca international stadium complex]
# Sharjah                                   [sharjah cricket stadium]
# Visakhapatnam     [dr. y.s. rajasekhara reddy aca-vdca cricket s...
# Name: venue, dtype: object

# %%
df_matches = df_matches[['id','venue','winner','target_runs']]

# %%
df_matches.rename(columns={'id' : 'match_id'},inplace=True)
# Out:
# C:\Users\shres\AppData\Local\Temp\ipykernel_10836\3260332357.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_matches.rename(columns={'id' : 'match_id'},inplace=True)

# %%
delivery = df_matches.merge(df_deliveries, on='match_id')

# %%
delivery = delivery[delivery['inning'] == 2]

# %%
delivery.shape
# Out:
# (111721, 20)

# %%
delivery['current_score'] = delivery.groupby('match_id')['total_runs'].cumsum()

# %%
delivery['runs_left'] =  delivery['target_runs'] - delivery['current_score']

# %%
delivery['balls_left'] =  120 - (delivery['over'] * 6 + delivery['ball'])

# %%
delivery
# Out:
#         match_id                   venue                 winner  target_runs  \
# 124       335982   m chinnaswamy stadium  Kolkata Knight Riders        223.0
# 125       335982   m chinnaswamy stadium  Kolkata Knight Riders        223.0
# 126       335982   m chinnaswamy stadium  Kolkata Knight Riders        223.0
# 127       335982   m chinnaswamy stadium  Kolkata Knight Riders        223.0
# 128       335982   m chinnaswamy stadium  Kolkata Knight Riders        223.0
# ...          ...                     ...                    ...          ...
# 230977   1426312  ma chidambaram stadium  Kolkata Knight Riders        114.0
# 230978   1426312  ma chidambaram stadium  Kolkata Knight Riders        114.0
# 230979   1426312  ma chidambaram stadium  Kolkata Knight Riders        114.0
# 230980   1426312  ma chidambaram stadium  Kolkata Knight Riders        114.0
# 230981   1426312  ma chidambaram stadium  Kolkata Knight Riders        114.0
#
#         inning                 batting_team           bowling_team  over  \
# 124          2  Royal Challengers Bangalore  Kolkata Knight Riders     0
# 125          2  Royal Challengers Bangalore  Kolkata Knight Riders     0
# 126          2  Royal Challengers Bangalore  Kolkata Knight Riders     0
# 127          2  Royal Challengers Bangalore  Kolkata Knight Riders     0
# 128          2  Royal Challengers Bangalore  Kolkata Knight Riders     0
# ...        ...                          ...                    ...   ...
# 230977       2        Kolkata Knight Riders    Sunrisers Hyderabad     9
# 230978       2        Kolkata Knight Riders    Sunrisers Hyderabad     9
# 230979       2        Kolkata Knight Riders    Sunrisers Hyderabad    10
# 230980       2        Kolkata Knight Riders    Sunrisers Hyderabad    10
# 230981       2        Kolkata Knight Riders    Sunrisers Hyderabad    10
#
#         ball    batter  ... extra_runs total_runs  extras_type  is_wicket  \
# 124        1  R Dravid  ...          0          1          NaN          0
# 125        2  W Jaffer  ...          1          1        wides          0
# 126        3  W Jaffer  ...          0          0          NaN          0
# 127        4  W Jaffer  ...          0          1          NaN          0
# 128        5  R Dravid  ...          0          1          NaN          0
# ...      ...       ...  ...        ...        ...          ...        ...
# 230977     5   SS Iyer  ...          0          1          NaN          0
# 230978     6   VR Iyer  ...          0          1          NaN          0
# 230979     1   VR Iyer  ...          0          1          NaN          0
# 230980     2   SS Iyer  ...          0          1          NaN          0
# 230981     3   VR Iyer  ...          0          1          NaN          0
#
#         player_dismissed dismissal_kind  fielder current_score runs_left  \
# 124                  NaN            NaN      NaN             1     222.0
# 125                  NaN            NaN      NaN             2     221.0
# 126                  NaN            NaN      NaN             2     221.0
# 127                  NaN            NaN      NaN             3     220.0
# 128                  NaN            NaN      NaN             4     219.0
# ...                  ...            ...      ...           ...       ...
# 230977               NaN            NaN      NaN           110       4.0
# 230978               NaN            NaN      NaN           111       3.0
# 230979               NaN            NaN      NaN           112       2.0
# 230980               NaN            NaN      NaN           113       1.0
# 230981               NaN            NaN      NaN           114       0.0
#
#        balls_left
# 124           119
# 125           118
# 126           117
# 127           116
# 128           115
# ...           ...
# 230977         61
# 230978         60
# 230979         59
# 230980         58
# 230981         57
#
# [111721 rows x 23 columns]

# %%
wickets = delivery.groupby('match_id')['is_wicket'].cumsum()
delivery['wickets_left'] = 10 - wickets

# %%
delivery['crr'] = delivery['current_score'] * 6 / (120- delivery['balls_left'])

# %%
delivery['rrr'] = delivery['runs_left'] * 6 / delivery['balls_left']

# %%
def result(row):
    return 1 if row['batting_team'] == row['winner'] else 0

# %%
delivery['result'] = delivery.apply(result,axis=1)

# %%
delivery.groupby('batter').agg(
    runs_scored=('batsman_runs', 'sum'),
    balls_faced=('batsman_runs', 'count'),
).sort_values(by='runs_scored', ascending=False)
# Out:
#                 runs_scored  balls_faced
# batter
# V Kohli                3288         2526
# DA Warner              2849         2090
# RG Sharma              2781         2257
# S Dhawan               2665         2150
# KL Rahul               2212         1689
# ...                     ...          ...
# AS Roy                    0            2
# AN Ghosh                  0            1
# Abdur Razzak              0            2
# Saurav Chauhan            0            1
# A Mukund                  0            1
#
# [594 rows x 2 columns]

# %%
delivery
# Out:
#         match_id                   venue                 winner  target_runs  \
# 124       335982   m chinnaswamy stadium  Kolkata Knight Riders        223.0
# 125       335982   m chinnaswamy stadium  Kolkata Knight Riders        223.0
# 126       335982   m chinnaswamy stadium  Kolkata Knight Riders        223.0
# 127       335982   m chinnaswamy stadium  Kolkata Knight Riders        223.0
# 128       335982   m chinnaswamy stadium  Kolkata Knight Riders        223.0
# ...          ...                     ...                    ...          ...
# 230977   1426312  ma chidambaram stadium  Kolkata Knight Riders        114.0
# 230978   1426312  ma chidambaram stadium  Kolkata Knight Riders        114.0
# 230979   1426312  ma chidambaram stadium  Kolkata Knight Riders        114.0
# 230980   1426312  ma chidambaram stadium  Kolkata Knight Riders        114.0
# 230981   1426312  ma chidambaram stadium  Kolkata Knight Riders        114.0
#
#         inning                 batting_team           bowling_team  over  \
# 124          2  Royal Challengers Bangalore  Kolkata Knight Riders     0
# 125          2  Royal Challengers Bangalore  Kolkata Knight Riders     0
# 126          2  Royal Challengers Bangalore  Kolkata Knight Riders     0
# 127          2  Royal Challengers Bangalore  Kolkata Knight Riders     0
# 128          2  Royal Challengers Bangalore  Kolkata Knight Riders     0
# ...        ...                          ...                    ...   ...
# 230977       2        Kolkata Knight Riders    Sunrisers Hyderabad     9
# 230978       2        Kolkata Knight Riders    Sunrisers Hyderabad     9
# 230979       2        Kolkata Knight Riders    Sunrisers Hyderabad    10
# 230980       2        Kolkata Knight Riders    Sunrisers Hyderabad    10
# 230981       2        Kolkata Knight Riders    Sunrisers Hyderabad    10
#
#         ball    batter  ... player_dismissed dismissal_kind  fielder  \
# 124        1  R Dravid  ...              NaN            NaN      NaN
# 125        2  W Jaffer  ...              NaN            NaN      NaN
# 126        3  W Jaffer  ...              NaN            NaN      NaN
# 127        4  W Jaffer  ...              NaN            NaN      NaN
# 128        5  R Dravid  ...              NaN            NaN      NaN
# ...      ...       ...  ...              ...            ...      ...
# 230977     5   SS Iyer  ...              NaN            NaN      NaN
# 230978     6   VR Iyer  ...              NaN            NaN      NaN
# 230979     1   VR Iyer  ...              NaN            NaN      NaN
# 230980     2   SS Iyer  ...              NaN            NaN      NaN
# 230981     3   VR Iyer  ...              NaN            NaN      NaN
#
#         current_score  runs_left balls_left  wickets_left        crr  \
# 124                 1      222.0        119            10   6.000000
# 125                 2      221.0        118            10   6.000000
# 126                 2      221.0        117            10   4.000000
# 127                 3      220.0        116            10   4.500000
# 128                 4      219.0        115            10   4.800000
# ...               ...        ...        ...           ...        ...
# 230977            110        4.0         61             8  11.186441
# 230978            111        3.0         60             8  11.100000
# 230979            112        2.0         59             8  11.016393
# 230980            113        1.0         58             8  10.935484
# 230981            114        0.0         57             8  10.857143
#
#               rrr result
# 124     11.193277      0
# 125     11.237288      0
# 126     11.333333      0
# 127     11.379310      0
# 128     11.426087      0
# ...           ...    ...
# 230977   0.393443      1
# 230978   0.300000      1
# 230979   0.203390      1
# 230980   0.103448      1
# 230981   0.000000      1
#
# [111721 rows x 27 columns]

# %%
final_df = delivery[['match_id','batting_team','bowling_team','venue','runs_left','balls_left','wickets_left','target_runs','crr','rrr','result']]

# %%
final_df = final_df[final_df['balls_left'] != 0]

# %%
final_df.dropna(subset=['rrr'],inplace=True)

# %%
final_df.isna().sum()
# Out:
# match_id        0
# batting_team    0
# bowling_team    0
# venue           0
# runs_left       0
# balls_left      0
# wickets_left    0
# target_runs     0
# crr             0
# rrr             0
# result          0
# dtype: int64

# %%
final_df['venue'].value_counts()
# Out:
# venue
# wankhede stadium                                                12680
# eden gardens                                                     9631
# ma chidambaram stadium                                           9591
# arun jaitley stadium                                             9190
# rajiv gandhi international stadium                               8020
# m chinnaswamy stadium                                            7443
# punjab cricket association is bindra stadium                     6228
# sawai mansingh stadium                                           5945
# dubai international cricket stadium                              5439
# zayed cricket stadium                                            4201
# narendra modi stadium                                            3982
# dr dy patil sports academy                                       3497
# sharjah cricket stadium                                          3181
# brabourne stadium                                                3163
# maharashtra cricket association stadium                          2808
# m.chinnaswamy stadium                                            1726
# kingsmead                                                        1719
# bharat ratna shri atal bihari vajpayee ekana cricket stadium     1541
# himachal pradesh cricket association stadium                     1519
# dr. y.s. rajasekhara reddy aca-vdca cricket stadium              1270
# supersport park                                                  1266
# new wanderers stadium                                             941
# st george's park                                                  805
# jsca international stadium complex                                711
# barabati stadium                                                  711
# newlands                                                          679
# maharaja yadavindra singh international cricket stadium           612
# holkar cricket stadium                                            594
# shaheed veer narayan singh international stadium                  564
# vidarbha cricket association stadium                              371
# barsapara cricket stadium                                         365
# de beers diamond oval                                             358
# buffalo park                                                      334
# outsurance oval                                                   248
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
unique_matches = final_df['match_id'].unique()
train_matches, test_matches = train_test_split(
    unique_matches, test_size=0.2, random_state=2
)

# %%
train_matches.shape
# Out:
# (768,)

# %%
test_matches.shape
# Out:
# (193,)

# %%
train_data = final_df[final_df['match_id'].isin(train_matches)]
test_data = final_df[final_df['match_id'].isin(test_matches)]

# %%
train_data['match_id'].value_counts().sort_values()
# Out:
# match_id
# 1178424     20
# 1082626     49
# 598068      50
# 1136608     51
# 1254093     53
#           ...
# 1426288    131
# 1426268    132
# 829811     133
# 829737     133
# 1359480    135
# Name: count, Length: 768, dtype: int64

# %%
test_data['match_id'].value_counts().sort_values()
# Out:
# match_id
# 829813       7
# 336021      38
# 1304082     49
# 829803      63
# 1254087     65
#           ...
# 392190     129
# 1426294    130
# 1216522    130
# 829777     130
# 1370350    131
# Name: count, Length: 193, dtype: int64

# %%
train_data = train_data.sample(frac = 1, random_state=42).reset_index(drop=True)
test_data = test_data.sample(frac = 1, random_state=42).reset_index(drop=True)

# %%
X_train = train_data.drop(columns=['result','match_id'])
y_train = train_data['result']

X_test = test_data.drop(columns=['result','match_id'])
y_test = test_data['result']

# %%
trf = ColumnTransformer(
    transformers=[
        ('trf', OneHotEncoder(sparse_output=False, drop='first'), ['batting_team', 'bowling_team', 'venue'])
    ], remainder='passthrough'
)

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',LogisticRegression(solver='liblinear'))
])

# %%
X_train['venue'].value_counts()
# Out:
# venue
# wankhede stadium                                                10798
# eden gardens                                                     7817
# ma chidambaram stadium                                           7808
# arun jaitley stadium                                             7573
# rajiv gandhi international stadium                               6822
# m chinnaswamy stadium                                            5683
# punjab cricket association is bindra stadium                     4791
# sawai mansingh stadium                                           4424
# dubai international cricket stadium                              3664
# zayed cricket stadium                                            3387
# narendra modi stadium                                            3271
# dr dy patil sports academy                                       2913
# sharjah cricket stadium                                          2678
# maharashtra cricket association stadium                          2556
# brabourne stadium                                                2329
# m.chinnaswamy stadium                                            1726
# kingsmead                                                        1473
# himachal pradesh cricket association stadium                     1186
# dr. y.s. rajasekhara reddy aca-vdca cricket stadium              1167
# bharat ratna shri atal bihari vajpayee ekana cricket stadium     1045
# supersport park                                                   929
# new wanderers stadium                                             698
# barabati stadium                                                  595
# st george's park                                                  590
# newlands                                                          550
# maharaja yadavindra singh international cricket stadium           490
# jsca international stadium complex                                469
# vidarbha cricket association stadium                              371
# de beers diamond oval                                             358
# holkar cricket stadium                                            292
# outsurance oval                                                   248
# barsapara cricket stadium                                         241
# shaheed veer narayan singh international stadium                  219
# buffalo park                                                      208
# Name: count, dtype: int64

# %%
X_test['venue'].value_counts()
# Out:
# venue
# wankhede stadium                                                1882
# eden gardens                                                    1814
# ma chidambaram stadium                                          1783
# dubai international cricket stadium                             1775
# m chinnaswamy stadium                                           1760
# arun jaitley stadium                                            1617
# sawai mansingh stadium                                          1521
# punjab cricket association is bindra stadium                    1437
# rajiv gandhi international stadium                              1198
# brabourne stadium                                                834
# zayed cricket stadium                                            814
# narendra modi stadium                                            711
# dr dy patil sports academy                                       584
# sharjah cricket stadium                                          503
# bharat ratna shri atal bihari vajpayee ekana cricket stadium     496
# shaheed veer narayan singh international stadium                 345
# supersport park                                                  337
# himachal pradesh cricket association stadium                     333
# holkar cricket stadium                                           302
# maharashtra cricket association stadium                          252
# kingsmead                                                        246
# new wanderers stadium                                            243
# jsca international stadium complex                               242
# st george's park                                                 215
# newlands                                                         129
# buffalo park                                                     126
# barsapara cricket stadium                                        124
# maharaja yadavindra singh international cricket stadium          122
# barabati stadium                                                 116
# dr. y.s. rajasekhara reddy aca-vdca cricket stadium              103
# Name: count, dtype: int64

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
#                                                    'bowling_team',
#                                                    'venue'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
scores = cross_val_score(pipe,X_train,y_train,cv = 10, scoring = 'accuracy' )
print(f'CV Accuracy scores: {scores}')
print(f'mean : {scores.mean()}')
# Out:
# CV Accuracy scores: [0.82040953 0.80832494 0.81649323 0.81750028 0.80866062 0.81794786
#  0.8130245  0.81078662 0.81884301 0.81669651]
# mean : 0.81486871093777

# %%
y_pred = pipe.predict(X_test)
print("Test Accuracy:", accuracy_score(y_test, y_pred))


print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))

print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Test Accuracy: 0.7418047714441813
# Confusion Matrix:
#  [[7966 2967]
#  [2704 8327]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.75      0.73      0.74     10933
#            1       0.74      0.75      0.75     11031
#
#     accuracy                           0.74     21964
#    macro avg       0.74      0.74      0.74     21964
# weighted avg       0.74      0.74      0.74     21964
